# %% [markdown]
# # **Project Name**    -  **EXPLORATORY DATA ANALYSIS ON GLOBAL TERRORISM DATASET**
#
# ---

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -** SUBHAM DAS THAKUR
# ##### **Team Member 2 -** ARUP MUKHERJEE
#
#
# ---

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ![GT_EDA.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The Global Terrorism database contains a detailed information about the terrorism, from 1970 to 2017. There are 181691 observations and 135 columns including date, month, year, country, city, region, attack type, killed, wounded, group name, weapon type etc. and it is a mix of categotical and numerical data values. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.
#
# We have shortlisted some important columns from this huge dataset for visualise the insights. We hereby state that we have used this data materials solely for non-commercial analysis and Visualization purpose.
#
# ---

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/subhamdasthakur1995/EDA_ON_GLOBAL_TERRORISM

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The problem in global terrorism is the persistent threat posed by acts of terrorism across different regions of the world. Terrorism is characterized by the intentional use of violence, intimidation, and fear to achieve political, ideological, or religious objectives. It poses a significant challenge to national security, public safety, and social cohesion.
#
# The objective of the Exploratory Data Analysis(EDA) is to understand the terrorist events around the world. By making use of interactive charts we have tried to make the exploration easy and more informative. We try to have a Birdseye view on global events and observe the trend of attacks across the globe.
#
# Lets explore and analyze the dataset and find some insights.
# Few questions are listed below...
#
# ---
#
# 1) What is the scenario of terrorism worldwide?
#
# 2) On which year the terrorist attacks are highest? and Is it increasing or decreasing onward?
#
# 3) Is there any month or particular day in month that is mostly targeted by the terrorist groups?
#
# 4) Which is the most affected region and most affected city by the terrorist attacks?
#
# 5) Is there any particular group name that attacks most?
#
# 6) What is the number of casualties ?
#
# 7) What is the correlation between different variables?

# %% [markdown]
# #### **Define Your Business Objective?**
#
# ---

# %% [markdown]
# Main objective is perform EDA on the given dataset and draw useful conclusions about general trends On GLOBAL TERRORISM and how factors governing Global Terrorism interact with each other.
#
# Terrorism continues to be a pressing global issue with far-reaching consequences for human lives, security, and social stability. However, the lack of a comprehensive and standardized dataset on global terrorism incidents poses significant challenges in understanding the patterns, trends, and underlying factors associated with this phenomenon. This information gap hampers the development of effective counterterrorism strategies, policy formulation, and evidence-based decision-making by governments, security agencies, and researchers.
#
# To address these challenges, there is a critical need for a project focused on creating a Global Terrorism Dataset that collects, cleans, standardizes, and analyzes data on terrorism incidents worldwide. Such a dataset would consolidate information from diverse sources, ensuring consistency and accuracy while providing a comprehensive view of the global terrorism landscape. By establishing a reliable foundation for research and analysis, this dataset would enable a deeper understanding of terrorism, facilitate evidence-based policymaking, and support the development of effective counterterrorism strategies to mitigate the threat posed by terrorism globally.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries
#
# ---

# %%
# Import Libraries

# numpy and pandas
import numpy as np
import pandas as pd

# visualization tools
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Dataset Loading
#
# ---

# %%
# Load Dataset

from google.colab import drive
drive.mount('/content/drive')
filepath = "/content/drive/MyDrive/GLOBAL TERRORISM DATASET/Global Terrorism Data.csv"
terrorism_df=pd.read_csv(filepath,encoding='ISO-8859-1')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-47-b9f551d0bf43>:6: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   terrorism_df=pd.read_csv(filepath,encoding='ISO-8859-1')

# %% [markdown]
# ### Dataset First View
#
# ---

# %%
# Dataset First Look
terrorism_df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count
#
# ---

# %%
# Dataset Rows & Columns count
print("There are {} rows and {} columns in the dataset".format(terrorism_df.shape[0],terrorism_df.shape[1]))
# Out:
# There are 181691 rows and 135 columns in the dataset

# %% [markdown]
# ### Dataset Information
#
# ---

# %%
# Dataset Info
terrorism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# #### Duplicate Values
#
# ---

# %%
# Dataset Duplicate Value Count
print(len(terrorism_df[terrorism_df.duplicated()]))
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values
#
# ---

# %%
# Missing Values/Null Values Count

# percentage of missing values in our dataset
missing_values = (((terrorism_df.isnull().sum()).sum())/terrorism_df.size)*100
missing_values
# Out:
# 56.481718962414206

# %%
#Checking for the null values
terrorism_df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Visualizing the missing values
terrorism_df.isnull()
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False        True     False        True
# 1         False  False   False  False        True     False        True
# 2         False  False   False  False        True     False        True
# 3         False  False   False  False        True     False        True
# 4         False  False   False  False        True     False        True
# ...         ...    ...     ...    ...         ...       ...         ...
# 181686    False  False   False  False        True     False        True
# 181687    False  False   False  False        True     False        True
# 181688    False  False   False  False        True     False        True
# 181689    False  False   False  False        True     False        True
# 181690    False  False   False  False        True     False        True
#
#         country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# ...

# %% [markdown]
# ### What did you know about your dataset?
#
# ---

# %% [markdown]
# The above dataset provides us the data on number of terrorist attacks on the basis of year and month on a particluar country and rigion. The corresponding attack type and weapon type is given and the city affected by attack is also given.
#
# The dataset contains **181691** entries with **135** features.
#
# **More than 50% values**  are Null, we need to clean the Dataset first

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
terrorism_df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
terrorism_df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State',
                          'region_txt':'Region','attacktype1_txt':'Attack_Type','target1':'Target','nkill':'Killed',
                          'nwound':'Wounded','gname':'Group','targtype1_txt':'Target_Type',
                          'weaptype1_txt':'Weapon_type','latitude':'Latitude',
                          'longitude':'Longitude','target1':'Target','city':'City'},inplace=True)

# %%
# creating dataframe with necessary columns only
terrorism_df = terrorism_df[['Year','Month','Day','Country','State','Region','City','Attack_Type','Killed',
              'Wounded','Group','Target','Target_Type','Weapon_type']]
terrorism_df.head(10)
# Out:
#    Year  Month  Day             Country       State  \
# 0  1970      7    2  Dominican Republic         NaN
# 1  1970      0    0              Mexico     Federal
# 2  1970      1    0         Philippines      Tarlac
# 3  1970      1    0              Greece      Attica
# 4  1970      1    0               Japan     Fukouka
# 5  1970      1    1       United States    Illinois
# 6  1970      1    2             Uruguay  Montevideo
# 7  1970      1    2       United States  California
# 8  1970      1    2       United States   Wisconsin
# 9  1970      1    3       United States   Wisconsin
#
#                         Region           City                     Attack_Type  \
# 0  Central America & Caribbean  Santo Domingo                   Assassination
# 1                North America    Mexico city     Hostage Taking (Kidnapping)
# 2               Southeast Asia        Unknown                   Assassination
# ...

# %%
# Dataset Describe
terrorism_df.describe()
# Out:
#                 Year          Month            Day         Killed  \
# count  181691.000000  181691.000000  181691.000000  171378.000000
# mean     2002.638997       6.467277      15.505644       2.403272
# std        13.259430       3.388303       8.814045      11.545741
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000       0.000000
# 50%      2009.000000       6.000000      15.000000       0.000000
# 75%      2014.000000       9.000000      23.000000       2.000000
# max      2017.000000      12.000000      31.000000    1570.000000
#
#              Wounded
# count  165380.000000
# mean        3.167668
# std        35.949392
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max      8191.000000

# %% [markdown]
# ### Variables Description
#
# ---

# %% [markdown]
# **Year:** Year of attack
#
# **Month:** Month of attack
#
# **Day:** Day of attack
#
# **Country:** Country which is affected
#
# **State:** State which is affected
#
# **Region:** Region which is affected
#
# **City:** City with casualties
#
# **Attack_type:** Type of attack
#
# **Killed:** Number of people Killed by the attack
#
# **Grounded:** Number of people Wounded by the attack
#
# **Group:** The name of terrorist Group
#
# **Target:** Who Or which are targeted
#
# **Target_type:** Type of target
#
# **Weapon_type:** Type of weapon

# %% [markdown]
# ### Check Unique Values for each variable.
#
# ----

# %%
# Check Unique Values for each variable.
for i in terrorism_df.columns:
    print(i,terrorism_df[i].nunique())
# Out:
# Year 47
# Month 13
# Day 32
# Country 205
# State 2855
# Region 12
# City 36674
# Attack_Type 9
# Killed 205
# Wounded 238
# Group 3537
# Target 86006
# Target_Type 22
# Weapon_type 12

# %%
#total unique Columns
terrorism_df.columns.nunique()
# Out:
# 14

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code
#
# ---

# %%
# Write your code to make your dataset analysis ready.
terrorism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   City         181257 non-null  object
#  7   Attack_Type  181691 non-null  object
#  8   Killed       171378 non-null  float64
#  9   Wounded      165380 non-null  float64
#  10  Group        181691 non-null  object
#  11  Target       181055 non-null  object
#  12  Target_Type  181691 non-null  object
#  13  Weapon_type  181691 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 19.4+ MB

# %%
#cleaned data
terrorism_df.head(10)
# Out:
#    Year  Month  Day             Country       State  \
# 0  1970      7    2  Dominican Republic         NaN
# 1  1970      0    0              Mexico     Federal
# 2  1970      1    0         Philippines      Tarlac
# 3  1970      1    0              Greece      Attica
# 4  1970      1    0               Japan     Fukouka
# 5  1970      1    1       United States    Illinois
# 6  1970      1    2             Uruguay  Montevideo
# 7  1970      1    2       United States  California
# 8  1970      1    2       United States   Wisconsin
# 9  1970      1    3       United States   Wisconsin
#
#                         Region           City                     Attack_Type  \
# 0  Central America & Caribbean  Santo Domingo                   Assassination
# 1                North America    Mexico city     Hostage Taking (Kidnapping)
# 2               Southeast Asia        Unknown                   Assassination
# ...

# %%
# creating new dataframe for the year 2014
terr_df_2014 = terrorism_df[terrorism_df.Year == 2014]

# %% [markdown]
# ### What all manipulations have you done and insights you found?
#
# ---

# %% [markdown]
# We have checked the infromation about the dataset with the terrorism_df.info() function and found that there are 2 float64 values, 3 int64 values and 9 object values are there.
#
# Finally, we made a cleaned data which is ready to analyze through different types of charts.
#
# Created a new dataframe of the year 2014 to analyze killed and wounded people in this year through the visualizaton.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# attacks by year
plt.figure(figsize=(20,5));
plt.xticks(rotation = 90)
sns.countplot(x=terrorism_df.Year);
plt.xlabel('Attack Year',size=15)
plt.ylabel('Number of Attacks each year',size=15)
plt.title('Attack_of_Years', size=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It allows us to quickly assess the distribution and frequency of different years in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 2014 appears to be witnessed of a huge number of terrorist attacks.
#
# 2014 onwards recorded a large increase in attacks of terrorism.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Businesses need to assess the potential risk of terrorist attacks during this period. Understanding the historical trends helps in implementing appropriate security measures to mitigate the risks and protect their employees, customers, and assets. This may involve strengthening physical security, implementing surveillance systems, enhancing access controls, and improving emergency response plans.
#
# ---

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# attacks by Month
plt.figure(figsize=(13,5));
plt.title('Attacks by Month', fontsize = 25)
sns.countplot(x=terrorism_df.Month);
plt.xlabel('Attack Month',size=15)
plt.ylabel('Number of Attacks each Month',size=15)
plt.title('Attack_of_Months', size=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It allows us to quickly assess the distribution and frequency of different months that are affected by terrorist attack in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  We can analyze from this visualization that **MAY** is the most affected month and **DECEMBER** is least attacked month in the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A high number of terrorist attacks in a specific month can lead to decreased consumer confidence and increased fear among the general population. This may result in reduced consumer spending, particularly in sectors such as tourism, hospitality, and retail.

# %% [markdown]
# ----

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

#attack by day
plt.figure(figsize=(20,5));
plt.title('Attacks by Day', fontsize = 25)
sns.countplot(x=terrorism_df.Day);
plt.xlabel('Attack Day',size=15)
plt.ylabel('Number of Attacks each day',size=15)
plt.title('Attack_of_days', size=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It allows us to quickly assess the distribution and frequency of different days in a month that are affected by terrorist attack in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart we can see, terrorist attck pattern is not that oriented on any specific day. It can be seen any day in the month.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Terrorist attacks can lead to significant disruptions in business operations. Depending on the scale and severity of the attack, businesses may face challenges in maintaining normal operations, including disruptions to supply chains, transportation, and logistics.
#
# ---

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

#Top 10 most affected countries
plt.subplots(figsize=(16,10))
import seaborn as sns
sns.barplot(x=terrorism_df['Country'].value_counts()[:10].index, y=terrorism_df['Country'].value_counts()[:10].values, palette='husl')
plt.title('Top 10 most affected countries', fontsize =25)
plt.xlabel('Country',size=15)
plt.ylabel('Number of attacks', size=15)
plt.xticks(rotation = 90, size=12)
plt.yticks(rotation = 0, size=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The code you provided is generating a bar plot using the Seaborn library to visualize the top 10 most affected countries by terrorist attacks

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see from this chart that the most affected country due to terrorist attacks is IRAQ followed by PAKISTAN and AFGANISTAN. INDIA is also afftected by several terrorist attacks and holds the 4th position in the row.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Terrorist attacks can disrupt the overall economy of a country. Business operations may be hampered, causing financial losses for companies operating within the affected area. Infrastructure damage, decreased consumer confidence, and disrupted supply chains can further exacerbate the economic impact.
#
# ---

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

#Top 10 Most Attacked States
plt.subplots(figsize=(15,10))
sns.barplot(x=terrorism_df['State'].value_counts()[:10].index, y=terrorism_df['State'].value_counts()[:10].values, palette='husl')
plt.title('Top 10 Most Attacked States',fontsize=20)
plt.xlabel('States',fontsize=15)
plt.ylabel('Number of Attacks',fontsize=15)
plt.xticks(rotation=90, size=10)
plt.yticks(size=10)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The code you provided is generating a bar plot using the Seaborn library to visualize the top 10 most affected States by terrorist attacks

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# e can see from this chart that the most affected state due to terrorist attacks is BAGHDAD.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A terrorist attack can disrupt the local economy, causing damage to infrastructure, businesses, and public services. The immediate closure of affected businesses can result in financial losses, decreased consumer spending, and reduced employment opportunities. It can also have a long-term impact on investment, tourism, and overall economic growth.
#
# ---

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

#Top 10 Most Attacked Region

plt.figure(figsize = (12,7))
sns.kdeplot(data=terrorism_df, x='Year', hue='Region')
plt.title('Terrorist Activities by Region in each Year',fontsize=15)
plt.xlabel('Years',fontsize=15)
plt.ylabel('Frequency of Attacks',fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart seems to visualize the number of attacks in different regions, specifically the top 10 most attacked states.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can find from this chart that MIDDLE EAST AND NORTH AFRICA is the most affected region in this dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The occurrence of terrorist attacks in a specific region can disrupt business operations, leading to temporary or long-term closure of facilities, interruptions in the supply chain, or damage to critical infrastructure. This can result in financial losses, decreased productivity, and potential delays in delivering goods or services.
#
# ---

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

#Top 10 most affected City
plt.subplots(figsize=(20,10))
sns.barplot(x=terrorism_df['City'].value_counts()[:10].index, y=terrorism_df['City'].value_counts()[:10].values, palette='husl')
plt.title('Top 10 most affected City', fontsize =25)
plt.xlabel('City', fontsize =25)
plt.ylabel('Number of attacks',fontsize =25)
plt.xticks(rotation =40)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The choice of this specific chart, a bar plot, is suitable for visualizing and comparing the frequency or count of attacks in different cities.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights the top 10 cities with the most recorded attacks. These cities have experienced a higher number of terrorist incidents compared to other cities in the dataset.
#
# From this chart we can insight the city with most attacks is BAGHDAD among the known cities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight can be valuable for businesses operating in or near these cities, as it helps them understand the potential security risks and take appropriate measures to ensure the safety of their operations, employees.
#
# Businesses operating in or planning to expand into areas affected by terrorism can use this information to assess the risks associated with specific cities. They can allocate resources, implement security measures, or adjust business strategies based on the level of threat in different locations.
#
# ---

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# 10 most attacked targets
plt.figure(figsize=(25,5));
plt.rcParams.update({'font.size':20});
plt.xticks(rotation = 00)
plt.title('Based on Attack type', fontsize = 25)
sns.countplot(y=terrorism_df.Attack_Type);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart suggests the use of a bar chart (specifically a countplot) to visualize the number of terrorist attacks Based on Attack type in an exploratory data analysis (EDA).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can find from this chart that BOMBING/EXPLOSION is the most favorite Attack type by the Terroriest gang in this dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The findings highlight the prevalence of private bombing and explosion as a major attack type. This can prompt businesses to reassess their security measures and protocols to better protect their premises, employees, and assets. It may involve strengthening physical security, implementing stricter access controls, and enhancing surveillance systems.
#
# ---

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# Number of Deaths in different years
plt.figure(figsize = (12,7))
terrorism_df.groupby(['Year'])['Killed'].sum().plot(kind='bar',colormap='summer')
plt.title('Number of Deaths in different years',fontsize=15)
plt.xlabel('Years',fontsize=15)
plt.ylabel('Number of Deaths',fontsize=15)
plt.xticks(rotation=90,size=11)
plt.yticks(rotation=00,size=11)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  To visualize the number of deaths caused by terrorism in different years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Number of deaths caused by terrorism is more between 2014 and 2018, with on an average >50K people being killed. High peak went to 2014 with 45K+ deaths.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights can help in identifying high-risk periods and locations, enabling businesses to allocate resources effectively and implement appropriate security measures.
#
# ---

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# Number of Wounded People in different years
plt.figure(figsize = (12,7))
terrorism_df.groupby(['Year'])['Wounded'].sum().plot(kind='bar',colormap='summer')
plt.title('Number of Wounded People in different years',fontsize=15)
plt.xlabel('Years',fontsize=15)
plt.ylabel('Number of Wounded People',fontsize=15)
plt.xticks(rotation=90,size=11)
plt.yticks(rotation=00,size=11)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the number of wounded caused by terrorism in different years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Number of wounded caused by terrorism is more between 2013 and 2017. High peak went to 2015.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  This could involve providing support for healthcare infrastructure, trauma counseling services, or partnering with local organizations working on post-terrorism rehabilitation.
#
#  ---

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# Top 10 Terrorist Organization with Highest Terror Attacks
plt.figure(figsize=(10,5))
sns.barplot(y=terrorism_df['Group'].value_counts()[:10].index, x=terrorism_df['Group'].value_counts()[:10].values, palette='husl')
plt.title('Top 10 Terrorist Organization with Highest Terror Attacks',fontsize=14)
plt.ylabel('Terrorist Groups',fontsize=15)
plt.xlabel('Number of Attacks',fontsize=15)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the top 10 terrorist organizations with the highest number of terror attacks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can see the maximum attacks are done by unknown or unidentified  groups. But from the known groups TALIBAN is prominant.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The lack of information about the groups responsible for these attacks makes it difficult to anticipate their motives, future actions, and targets. This uncertainty can hinder business decision-making processes and risk assessment.
#
# ---

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

#Top 10 Terrorist Organization with Highest Terror Attacks
plt.figure(figsize=(10,5))
sns.barplot(y=terrorism_df['Target'].value_counts()[:10].index, x=terrorism_df['Target'].value_counts()[:10].values, palette='husl')
plt.title('Top 10 Terrorist Organization with Highest Terror Attacks',fontsize=14)
plt.ylabel('Terrorist Groups',fontsize=15)
plt.xlabel('Number of Attacks',fontsize=15)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The given code is generating a bar plot using the seaborn library (sns.barplot). It visualizes the top 10 terrorist organizations with the highest number of terror attacks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this we can insight that CIVILIANS are highly affected by these terrorist activities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It indicates a higher risk to the local population.
#
# ---

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# Top 5 most used weapons types in terror attacks
plt.figure(figsize=(10,7))
sns.barplot(x=terrorism_df['Weapon_type'].value_counts().head().index, y=terrorism_df['Weapon_type'].value_counts().head().values,palette='flare')
plt.title('Top 5 Most Used Weapon types',fontsize=15)
plt.xlabel('Weapon Types',fontsize=15)
plt.ylabel('Number of Weapon Used',fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It visualizes the top 5 most used weapon types in terrorism incidents.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most used weapon type is EXPLOSIVES followed by FIREARMS.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  The security industry, including companies specializing in explosives detection, surveillance systems, and security consulting, may experience increased demand for their products and services. Businesses operating in this sector could benefit from providing advanced security solutions to combat the threat of explosives.
#
#  ---

# %% [markdown]
# #### Chart - 14

# %%
# Chart - 14 visualization code
terrorism_df.hist(figsize=(12,12))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# his can be useful for identifying patterns, outliers, and understanding the overall shape of the data distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ---

# %% [markdown]
# #### Chart - 15

# %%
# Chart - 15 visualization code

#Top 10 countries with max people killed in 2014
plt.subplot(1,2,1)
terr_df_2014.groupby(['Country'])['Killed'].sum().sort_values(ascending = False).head(10).plot(kind='bar',colormap='RdBu')
plt.title('Top 10 countries with max people killed in 2014',fontsize=15)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Number of people killed ',fontsize=15)
plt.xticks(rotation=90)

#Top 10 countries with max people wounded in 2014
plt.subplot(1,2,2)
terr_df_2014.groupby(['Country'])['Wounded'].sum().sort_values(ascending = False).head(10).plot(kind='bar',colormap='spring')
plt.title('Top 10 countries with max people wounded in 2014',fontsize=15)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Number of people Wounded',fontsize=15)
plt.xticks(rotation=90)
plt.gcf().set_size_inches(15, 5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The side-by-side bar plots allow for easy comparison between the two categories: people killed and people wounded. This comparison helps identify countries where the severity of casualties differs, providing insights into the impact of terrorist attacks on human lives.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In 2014 which is most affected year due to terrorist attack, the maximum number of people killed (more than 12500) and the maximum number of people wounded (more than 15000) are from IRAQ (most affected country).
#
# ---

# %% [markdown]
# #### Chart - 16 - Correlation Heatmap

# %%
cor = terrorism_df.corr()
cor
# Out:
# <ipython-input-79-f8dcc68a718d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = terrorism_df.corr()
#              Year     Month       Day    Killed   Wounded
# Year     1.000000  0.000139  0.018254  0.015341  0.015273
# Month    0.000139  1.000000  0.005497  0.003463  0.002938
# Day      0.018254  0.005497  1.000000 -0.003693 -0.001268
# Killed   0.015341  0.003463 -0.003693  1.000000  0.534375
# Wounded  0.015273  0.002938 -0.001268  0.534375  1.000000

# %%
# Correlation Heatmap visualization code

plt.figure(figsize=(10,10))

sns.heatmap(np.round(cor,2),annot=True,cmap='BuPu')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps are commonly used to explore and visualize the correlation between variables in a dataset. By providing a matrix of correlation values, the heatmap allows for easy identification of relationships and patterns between pairs of variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  This shows how much related is one parameter to the other in the dataset.
#
#  -----

# %% [markdown]
# #### Chart - 17 - Pair Plot

# %%
# Pairplot visualization code
sns.pairplot(terrorism_df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By creating scatter plots for each pair of variables, the pair plot allows for a comprehensive view of how variables relate to one another. It enables the identification of potential patterns, trends, and correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# the pair plot includes scatter plots that represent the relationship between two variables. Scatter plots can reveal the presence of linear or nonlinear associations, clusters, outliers, or any other interesting patterns. They help in understanding how variables vary together and provide a visual indication of potential correlations or dependencies.
#
# ---

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
#
# ----
# Explain Briefly.

# %% [markdown]
# ~ Develop risk mitigation strategies and security measures tailored to
#
# ~ pecific regions or scenarios.
#
# ~ dentify hotspots or clusters of terrorist activities to prioritize resource allocation and emergency preparedness.
#
# ~ Identify high-risk regions or countries based on the frequency and severity of terrorist attacks.
#
# ~ Identify the invasive unknown groups that attack most. It will require proper investigation.
#
# ~ Explore factors such as time, location, or attack methods that are associated with higher casualties. As we seen a higher attacks in 2014 onwards. So it can be said that these Activities are increasing.
#
# ~ Additional resources or security nmeasures are needed to those cities with most attcks.
#
# ~ Monitor social media or online platforms to identify emerging threats or extremist activities.
#
# ~ Analyze the impact of terrorist attacks on business continuity, including disruptions to supply chains, transportation networks, or critical infrastructure.
#
# ~ Evaluate the long-term socio-economic impacts of terrorism on specific regions or industries.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# After observing different graphs, we obtained the following results:
#
# ---
#
#
# **2014** : Year with most number of attacks.
#
# **5th month(May)** : Month with most number of attacks.
#
# **15th day of month** :  Day with most number of attacks.
#
# **Iraq** : Country with most number of attacks.
#
# **Baghdad**: State with most number of attacks.
#
# **Middle East and North America** : Most attacked Region.
#
# **Bombing /Explosion** : Most attack based on attack type.
#
# **Kiiled** : Maximum people killed due to terrorism in 2014.
#
# **Wounded** : Maximum people wounded due to terrorism in 2015.
#
# **Civilians** : Civilians are the most target of these terrorist activities.
#
#
# **Explosive** : Most used weapon type in attacks.

# %% [markdown]
# # **THANK YOU**
#
# ---
